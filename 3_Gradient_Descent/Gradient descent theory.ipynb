# %% [markdown]
# *y = mx+c*
#
# mean squared error = 1/n sum(yi - ypredicted)**2
#
#
# mean squared error is also called cost function
#
# y predicted = mx + b
#
#
# Gradient descent algorithm that finds best fit line for given training data set
#
#
# slope = change in y / change in x

# %% [markdown]
# ![derivates_equation.PNG](attachment:derivates_equation.PNG)

# %% [markdown]
# partial derivative gives slope
#
# as i got the direction i need step -> which we need learning rate

# %% [markdown]
# ![LearningRate.PNG](attachment:LearningRate.PNG)

# %% [markdown]
# ![learning%20rate%20slope.PNG](attachment:learning%20rate%20slope.PNG)
