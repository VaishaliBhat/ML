# %% [markdown]
# 1) Start with K centroids by putting them at random place, k=2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ELBOW METHOD

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C=K

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# AS YOU INCREASE THE CLUSTER, YOU DECREASE THE ERROR

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ACCORDING TO THIS, GOOD K NUMBER WUD BE 4
